# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarathi666/Generative_AI/blob/main/AIPowered_LanguageTranslator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ping -c 3 google.com


# !pip install langchain transformers streamlit sentencepiece
# !pip install langchain-community
from langchain.llms import HuggingFacePipeline
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
import streamlit as st

# Supported language pairs (extendable)
language_pairs = {
    "English to French": ("Helsinki-NLP/opus-mt-en-fr", "en", "fr"),
    "French to English": ("Helsinki-NLP/opus-mt-fr-en", "fr", "en"),
    "English to German": ("Helsinki-NLP/opus-mt-en-de", "en", "de"),
    "German to English": ("Helsinki-NLP/opus-mt-de-en", "de", "en"),
    "English to Hindi": ("Helsinki-NLP/opus-mt-en-hi", "en", "hi"),
    "Hindi to English": ("Helsinki-NLP/opus-mt-hi-en", "hi", "en"),
}

# Streamlit UI
st.set_page_config(page_title="Multilingual Translator", layout="centered")
st.title("🌐 Multilingual Translator (Local & Real-time)")

# Language selector
selected_pair = st.selectbox("Choose Language Pair", list(language_pairs.keys()))
model_name, src_lang, tgt_lang = language_pairs[selected_pair]

# Load translation pipeline
@st.cache_resource
def load_translator(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
    return pipeline("translation", model=model, tokenizer=tokenizer)

translator = load_translator(model_name)

# Input
user_input = st.text_area(f"Enter text in {src_lang.upper()}:", height=150)

# Translate
if st.button("Translate"):
    if user_input.strip():
        with st.spinner("Translating..."):
            output = translator(user_input, max_length=100)
            translated_text = output[0]["translation_text"]
            st.success(f"**Translation ({tgt_lang.upper()}):**")
            st.write(translated_text)
    else:
        st.warning("Please enter some text to translate.")
import streamlit as st

# Supported language pairs (extendable)
language_pairs = {
    "English to French": ("Helsinki-NLP/opus-mt-en-fr", "en", "fr"),
    "French to English": ("Helsinki-NLP/opus-mt-fr-en", "fr", "en"),
    "English to German": ("Helsinki-NLP/opus-mt-en-de", "en", "de"),
    "German to English": ("Helsinki-NLP/opus-mt-de-en", "de", "en"),
    "English to Hindi": ("Helsinki-NLP/opus-mt-en-hi", "en", "hi"),
    "Hindi to English": ("Helsinki-NLP/opus-mt-hi-en", "hi", "en"),
}

# Streamlit UI
st.set_page_config(page_title="Multilingual Translator", layout="centered")
st.title("🌐 Multilingual Translator (Local & Real-time)")

# Language selector
selected_pair = st.selectbox("Choose Language Pair", list(language_pairs.keys()))
model_name, src_lang, tgt_lang = language_pairs[selected_pair]

# Load translation pipeline
@st.cache_resource
def load_translator(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
    return pipeline("translation", model=model, tokenizer=tokenizer)

translator = load_translator(model_name)

# Input
user_input = st.text_area(f"Enter text in {src_lang.upper()}:", height=150)

# Translate
if st.button("Translate"):
    if user_input.strip():
        with st.spinner("Translating..."):
            output = translator(user_input, max_length=100)
            translated_text = output[0]["translation_text"]
            st.success(f"**Translation ({tgt_lang.upper()}):**")
            st.write(translated_text)
    else:
        st.warning("Please enter some text to translate.")
# Out:
# /bin/bash: line 1: ping: command not found
# ...
# 2025-04-15 10:24:39.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-15 10:24:39.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-15 10:24:39.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-15 10:24:39.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-15 10:24:39.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-15 10:24:39.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-15 10:24:39.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
